# %% [markdown]
# # Text Classification Exam
#
# Welcome to the Text Classification Practical Exam. In this exam, you will be tasked with building, training, and evaluating an NLP model to classify text data. You are provided with a labeled dataset containing both the text and its corresponding class labels.
#
# Your objective is to develop a model that accurately predicts the class of the given text. Make sure to follow best practices in data preprocessing, model selection, and evaluation to achieve optimal results.
#
# Good luck!
# ___

# %% [markdown]
# # Install and Import Needed Libraries

# %% [markdown]
# You can use `pyarabic` or any other library to pre-process and clean the Arabic text.

# %%
# !pip install pyarabic
# Out:
# Collecting pyarabic
#   Downloading PyArabic-0.6.15-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from pyarabic) (1.16.0)
# Downloading PyArabic-0.6.15-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: pyarabic
# Successfully installed pyarabic-0.6.15

# %% [markdown]
# # Download the Dataset

# %% [markdown]
# Please note that you are allowed to take a subset of this dataset, the reason for that is it might take a long time to train the model on.

# %%
# !kaggle datasets download -d khaledzsa/sanad
# !unzip sanad.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/khaledzsa/sanad
# License(s): unknown
# Downloading sanad.zip to /content
#  98% 70.0M/71.4M [00:00<00:00, 148MB/s]
# 100% 71.4M/71.4M [00:00<00:00, 138MB/s]
# Archive:  sanad.zip
#   inflating: sanad.csv

# %%
import pandas as pd
df = pd.read_csv('sanad.csv')
df.head()
# Out:
#                                                 text    label
# 0  https://example.com/resource/الشاٌرقة -ْ محمِد...  Culture
# 1  https://example.com/resource/اَنِطٌلقّتَ ٍفٍيّ...  Culture
# 2  https://example.com/resource/أُقيًمٌتِ مِساءُ ...  Culture
# 3  https://example.com/resource/بٍاسُمةَ يًوٌنٍس ...  Culture
# 4  https://example.com/resource/قُرر اَتحِاد اًلْ...  Culture

# %% [markdown]
# # Data Exploration

# %% [markdown]
# Before diving into preprocessing and model building, it’s important to first explore the dataset to understand its structure, distribution, and key characteristics. This step will help you gain insights into the data and guide your decisions in subsequent steps. Here’s what to consider:
#
# 1. **Inspect the Data**:
#    Start by looking at the first few rows of the dataset to get a sense of its structure. Check the columns, data types, and a few sample entries. This helps to ensure that the data is loaded correctly and gives you an initial overview of the content.
#
# 2. **Check for Missing Values**:
#    Identify if there are any missing values in the dataset.
#
# 3. **Distribution of Labels**:
#    Examine the distribution of the target labels (classes).
#
# 4. **Text Data Characteristics (Bonus)**:
#    Analyze the length of the text data. It is useful to calculate the number of words or characters in each text sample to understand how long the texts are. This will help you set a suitable `max_length` for tokenization and padding later. You can plot a histogram of text lengths to visualize the distribution.
#
# 5. **Common Words and Vocabulary (Bonus)**:
#    Explore the most frequent words in the text data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39885 entries, 0 to 39884
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    39885 non-null  object
#  1   label   39885 non-null  object
# dtypes: object(2)
# memory usage: 623.3+ KB

# %%
df.isna().sum()
# Out:
# text     0
# label    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.tail()
# Out:
#                                                     text label
# 39880  https://example.com/resource/أعلّنت شّركٌةً بّ...  Tech
# 39881  https://example.com/resource/بُتٍاَرٌيًخَ 28ْ ...  Tech
# 39882  https://example.com/resource/دبَيُ:َ «ُاَلخليج...  Tech
# 39883  https://example.com/resource/LٌG GًS2ْ9ً0 Coْo...  Tech
# 39884  https://example.com/resource/تنطًلقٍ اٌليومّ َ...  Tech

# %%
df['label'].unique()
# Out:
# array(['Culture', 'Finance', 'Medical', 'Politics', 'Religion', 'Sports',
#        'Tech'], dtype=object)

# %%
df['label'].value_counts()
# Out:
# label
# Politics    6334
# Medical     6292
# Culture     6098
# Finance     6095
# Tech        5979
# Sports      5859
# Religion    3228
# Name: count, dtype: int64

# %%
df.value_counts()
# Out:
# text                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# https://example.com/resource/"الْلٌه سيًمنعنًيِ"َاجْتِمع ُيوُماُ أٌصُحاِبَ رسِول اٍلله-ِ ُصِلٌى الله علُيه وسّلمٍ-ُ َفقاٌلوا: ٍواللٌه مَا سَمعتّ قٌرًيْشّ ْهذاً القْرآْنُ ّيجًهٍر ٌلْهٌاٍ بّهٍ ّقِطٌ، فًمًَُنٌ ْرّجًلٍ يسمٌعهَمً؟ َفقالً ِعُبدَالَلٌهِ ًبن مّسَعودُ:ْ أناّ، ٌقالوْا: ْإِنا َنَخشًاّهَم ٍعٍليكٍ.ٍ إنّمٍا نرَيدُ ٌرجِلاًُ ٌلّهُ ّعّشٍيرةِ من اًلقٌوُمً إّن ٍأْرٌاّدٍوهّ.ُ ْقًاِلُ: دعوّنيّ فًإن ٍاًللهٌ ٌسيُمنعنٍي.فغدِا ُاِبنً ِمسعّوّدُ ْحْتَىْ أٍتى ْالمٌقاًم ِفي ّاَلْضحىً وْقٍرُيًش ٍفي أندِيٍتهًا.ِ حتٍى ّقِاًم َعَنٌدَ اِلْمقامّ ٍثٍمٌ قرأ ًرافٍعّاًٌَ ْصوَته ْالرحمُنْ عٌلم الّقْرآٌن..ْ ٌفٌجعِلِوُاٍ يقَولونَ: َماٌذْاِ قّال ابن ٍأمَ عبد؟قالواُ: ْإُنّه ْيْتّلًو ٌبًعًض ْماّ ُجَاًء به مّحْمد.ٌفٌقامِوا ٍإّلٌيهٍ،ٍ فجعلَوا ُيضٍربٍونِهْ،ّ ٍوجٌعل يُقٌرأٍ حّتِى ٌبلغ مٌنّهَاٍ ُمّاُ ُشاءٍ اللّه أْن يّبِلًغً. ًثمَ َانصرّف إلىْ ِأْصُحابٌهَ وقُد أثرّوا في ِوجهه فقالوْا ّلهَ: ّهذاْ اٌلّذي خّشًيِناِ ْعٌليّكً.ّفّقالَ لهمً:ً ٌمِا كان أٍعدٌاء الَلٌهٌ أًهون َعلٌيّ ُمٌنهّمٌ ِاًلُآن،ً ّوٌلُئْنٌ َشئٌتم لأٌغّادٍيْنهمّ بَمّثَلهاٌ غدِاً.ُقُالَوا: لاّ حًسًبك،ٍ قدً اسمعًتٌهُمَ ًمًا يكرُهون. قٍبٍلْ أن تِحِاٌسبُوامُرّ رّجل ْمن ِقّبَيّلة مراِدٌ بأوٍيْسٌ َالقرنْي ْفقٍاِل ّله:ُ ًكٍيٌفً ُأصِبٌحتَ يًاٍ أوٌيِس؟قاٌلّ: أَصّبحٌتَ أٌحٌمّد ٌالَلُهٍ.قَالٌ:ْ كيًف ٍاَلّزمان ٍعلٌيِك؟قال:ّ ُيٌاُ ٌأخَا ٍمّرٌاَدّ، إنَّ الزمّاَن َوٍذُكٍره لم يدع في اِلّأٍرِضٌ لمٌؤمٌن فّرَحاً. وٍإًنٍ ٌعُلمًهً بِكتاْب ِاًلله لمِ يًدعّ فيْ مالهٍ فضة ًولُاٌ ُذٍهبًاًٌَ،ِ ِوإِنَ قيًامه بِالحقّ لُمَ ٌيدع له ًصديُقاًٌ.ٌفقاِلْ ٌاٍلًرجل: حُدثّنيً ّبحٌدّيُث سِمّعًته من رسْولِ ِاِلٍلْهً صّلوات ًاٌللُهٍ ًعِلِيهٍ.َقّاُل:ّ ٍيا أخٌا ًمُرِاد،َ مُاِ ّشٍهدتَ ًرسٍولَ ِاللًه فأِحَدُثُك ٍعَنه ولكنَ افعلوٍا ْكما ّقُال ّلكم ٍرٍسوْل َالِلهٌ ٍحاًسبٌواّ أنفسِكم ِقبّلَ أنٌ ًتًحاسبّوا فإن اٌللّهُ جعَل اِلٌدنّياْ قنّطرُةِ ُللآُخَرٍة فٍاْعتٍبروْهَا.ٍ                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# https://example.com/resource/ذٍكرت ٌالسنة اْلٌنَبوِيةّ ٌأًن أًسْمى مّرُاَتُب اٍلٍعٌبْاْدَة َمرتًبُة ٌالّإحًساِن، اِلتْي فسرٍهاَ الِرِسول ِصٍلٌىٌ ْاَللٍه عٍليه ْوّسُلمً ْبقِوًلّه:ٌ (اِلإحسانٍ أن ٍتًعِبد اللّهِ كأنكِ تَرْاّهِ ٍفْإنٌ لّمٍ تكن تّراهً ّفًإٌنٌهٍ يرَاك)ِ . ٍوَكمْ َمدحّ اٍلٌلهِ ْالذين ّيخَشوُنْ رَبهَم بالغيب ّفيٌ اْلًقرآْنً الّكريُم،ٍ وْبيًّنٍ الحق ّحِسِن ٍالعّاِقٍبٍةَ َلٍأناس وُصِفًهم ُبَقوله ْوأّمَا منَ ْخُاٌفّ مقُاْمْ ّربِهً َوِنًهْىً النفسٌ عِنً ٌاْلّهٌوىٌ . ِفإّن اِلّجّنة َهي ُاْلمأوْى ّ. إٍنً اٌلَمٍقًدم ُعلى اَلٌجرّيِمّة لْاٍ يْقَومٌ بٌهاٍ َإّلاً فيْ ظِل اًعٍتبٌاٌراٍتَ عِدٌة أخُصَهاّ: ُأن ًأحداًٍِ لاَ ٌيُرّاَهْ وأن ُمن َيرٍاهْ ًفهوِ مشاَركّ ًلهً أو يمٌكن ٍأًنٌ ًيكوَن كِذٌلَكُ،ً ُوأٌنًهً ُأقوىُ ًمٍن اٍلٌرْائَيِ َوْقاٍدر عْلَىْ الُبطَش به ٍإن ّتكلم ٌ. ًوَأّنٍه سيُعطيٍ ِاُلراّئٍي ْنصيْباًٍ ٌمٍما سّلبْت شَماله أوِ َيقًدم لهٍ ّمِنفعةً ْماَديَة ٌأٍوً ّمعنوّيٍةَ ُفإذٌاْ ْتأٍكْدِ لٍهّ ٍذلكّ بمقُايِيسَ َالُبشرٌ أْقدم علْىَ سوِءّ صَنٍيِعهَ، ِوما ذُلكُ ّإلٍا لًضْعف ْالِإيمٍان ْ.ِ وأمّاُ ِالٍمسْلمْ ِاْلصٌاْدقَ فّي ُاِلٌاعْتقاٍد، ُفإنَهْ إن فكْر في الجريمُةّ،ّ أتُتٌه العَنًاصَرٌ ٍالُسابًقٌةّ ٌجًمَعاء ِفٍحًاٌلًتْ بينَهْ ِوبّين اِلَإقدام علِيهُاً، ِإٍذا غٌابُت ُعينٌ ٌاًلبُشرٌ ُفعين ًاللهَ ْلُا ّتنام اْللًهٌ ٍلًا إلِه َإلْاُ ِهوِ اِلحِي الٌقيًومٌ لا ٌتأًخذهٌ ّسنٌةَ ولِاٌ َنوّم . ِ. ّ.ً،ً لا تْدِرًكه َاَلٌأبًصَارَ َوهٌوٌ يدٌرٌك ٍاًلأُبَصاٌر ٌوُهوٌ اللَطيُفً اْلخبيُرٍ .ِإن رسولٌ ّاٌلُله صًلىْ الْله ًعلْيه ِوٌسلم ذْكِر حالٌات ٌلأناسِ ٌيسًرت لهِمّ َسٍبْلً الِمعصية، فٍلماِ ُهْمواَ مِنًعُهم اٍلخوف ِمّنَ ْاٍلِلّه،ٍ فِكاُن ٌإٍقلاعُهم عّنٍ المُعصيّةٍ سبٌبْاًٌّ ٍفي نجِاتهمً ُمْنْ التهًلُكٍةَ،ُ ّكما فِيِ قصْةِ الُثّلاثًة اًلذّين آّووا ٌإٌلٌى اٌلغارً فٌسقٍطٍتَ صخرة ّعِلى ِبّاْبٌهٌ فأّغّلقته ِفِقِالَوا لا سٌبٍيلِ ُلٌلْخرْوجّ ٌإلّا ًبٌالّتوّسل ْإلِىٍ اللٍهً بًصالحً اّلعملّ، وٌمٍما ذكرٌه ًأحِدًهم أنِه جلًسُ ًمنٌ اَمرَأة مَجلّسَ ًالرِجلَ من ُزَوٌجٍته فلٌمِا ٍهِم بهًاُ أقِلْعّ ّعْن اٍلَفًعًل َخُوٍفْاًٍ مًنْ اًلله ُ.َإن شعوُرِ ٍالّعبًدٌ ًبْمرِاِقٍبةً ِالْله ًيَدٌفعه ٍإٍلُىٍ اُلاستًحُيٌاء من ّاٍلوقوعً في ُالٌمًعِصية، ْوُرحم ِاِلله ًمن قِال:ٌإذُاْ مِاٌ خّلُوُتّ فٍلٌاّ َتقل خلِوٌت .ٌ ً.َ ْولْكنٌ ْقْلّ عُليًٍّ ٌرَقيبِوْلّاٍ تحْسبَن ٌاللهِ ّيغِفلِ ِسُاًعًةْ . ُ. وِلاً أًن مٌاً ْتخفيْ علُيٌهٍ ِيّغيبوُإذاْ كنُا ًقدِ ًتحدثنِا عنّ ِالرِقابةّ ٍالٌإّلُهيةً ٍوٌآثارهِاْ ْفيّ ّحَمل ٍالْمِسٌلّم عَلِىِ ْالٍإٌقلاْعَ عن ٍالجريٍمَةَ فِإن ذلًك ُلا يدفٌع إَلّىٌ ٍاُلٍيْأِس أُو الٍقنِوَط ِمٍن ُرٍحًمةً الٍلهِ إٌذا ًوٍقِعًت ِاِلًجرًيُمةِ،ّ فُاٍلحٍقُ سُبحانهٍ ٍخلقٌ َالإنَسٍاًنّ َبُتكوٍيٌنهً َصاُلِحُاًْ ٍلٌلطُاعْة وّاَلٌمعصيَة وًاِلَخْطٌأ َواّلّصَواِب . ُ(ِباْسٍتْثنِاَءِ اَلْأِنبيّاّءً)ُ،ُ قِاّلَ ِتعٍالىّ إِنا َهديِناُه ٌالْسبٌيُل ّإْمٌاٌ ْشِاُكٌراًٍ ًوإّمّاّ ٌكفْوًراًّ .ِ وٌذّكَرً ْالقْرٍآٍنَ أٍنٌ نِزًغ الَشيُطِاٍنِ لًلإنسانْ ممكن،َ وْرسمٍ ِلهّ ُاْلٌسّبِيَلّ َلْلوُقايَة َمنَهً،ٌ ًقْاٍلِ تعّالىً َوَإْمٍاَ ِينَزغنًكْ ٌمن الشيّطِان نًزغِ فٌاستعذُ ِباٌلًلٌه ٍإنُه هو ِاُلٌسميع ُالعَليٌمٍ ّ. وذًكرُ أِن الُمتقين قد َيْسوُل لٍهٍم ًاًلْشُيطُاُنِ ِشيئَاًِ ما إٌلاْ ُأّنهم ٍيختلَفُون ُعًنٌ ّغًيِرّهمّ ِفَي ِهذٍاّ الٌموطن ٍإٍن ٌاٍلذينٍ اتٌقِوْاٍ ْإًذٌا ٌمسًهمّ طاّئفُ ُمن ٍالّشيٌطاِن ًتْذكٍرْواّ فإٌذٍا هم مبْصرونٍ، وٌإٍخوانًهٍم ُيمٌدْونهمَ ٌفِيٍ اّلّغٌي ثم ُلا يقصرون .فُإذاً ّتنّاٌسوًاْ ٌذلكْ، َووقعَتِ مْنهمٌ َاَلٍمعًصيْة،ٍ َفإنَ َاَلُلًهْ لمْ ٍيٌيِئِسٌهمِ مٌن رحٍمتّه،َ لّأن ًاِليَأٍس َيُدْفعِ ٍإٍلىّ ْاقِتٍرًاّف اْلّمعاصي ُواًلتٌحٍوِلً َإلَى ْشخصيُةْ ُعًدوٍاِنيّة، قالَ تٍعالىْ واّلذين ٍإذاْ فًعّلْوِاَ فّاحشٍة ْأو ظلْمواً أُنّفُسهًمّ ذِكرُوّاّ ُاٍلٌلهْ ّفاسُتَغٌفروٍا ْلذّنوبٍهم ٍوٌمن ّيغَفرَ ِاَلٌذّنوبٍ ْإَلٍا الًلهٌ ولمُ ّيصرّواَ ُعِلِى ًمّا فٍعًلّوا ِوهْم ّيعِلُمَونٍ، أوْلُئك ًجزٍاَؤِهمً َمْغِفّرُة ّمنِ رٍبهِم َوِجًنٍاِتِ تجْرِي منُ ٌتحِتهاٌ َاْلٌأٌنهٍاُرْ . ُ. .ُ .وحسُبُنْا اٍلَقوْل الجٌاًمع ْقلُ يًاٍ ّعبادًي اُلذُين ُأِسرًفَوا عٍلِى َأِنفسهَم لاٌ تقُنٍطوا ّمنَ َرْحًمةً ُاُلْلهْ ٌإنُ اللهِ ُيَغَفرْ َالذنوٍب جمٍيٌعاًِ إنْهْ هٌو ًاًلغَفور ْاًلْرِحيم ً.* ًعٌميدً كليٌةٍ أصّولٍ الدٌينً ّفيٌ الأًزهرُ                                                                                            ...
# https://example.com/resource/ذٌكَرًتٌ اّلٍشُرطة ٍالإثُيَوِبْية أُن ّمدّيَر ٌمْشرِوًعْ ٍسدّ الُنٍهِضة ِعثر ٌعْليّهّ َمقتَوِلِاًَ،ّ ٍأمس ٍالٍخّميِس.وٍقَالٌ زّيّنْوٌ جماٍلّ، رئًيًسِ اَلشرطة، ّإن المٌهٌندسٌ ِسٍيميجنّيوٍ بٍيٌكيلي أًصيّبٌ بِطلْقٌ نْاَرٌي ٌفي ِاِلرُأَسِ مَنّ ٌاِلُخًلفِ، وإِنهُ تم ّاِلعثوِرّ ُعُلًى مسٍدسٌ ٌدّاخٍل السٌيًارٍةّ،ْ وتٌحاٍوْلٌ ٍاًلَسلِطاٌتِ ًالتِوصلِ إَلى هويٌة ماْلكٍ السلاَحً.ُوقُدْ عٌثًرْ ّعٍلِى ُجٍثِة سيًميجٌنِيَوً بيِكَيًلي دٍاخٍل ّسُياًرةَ دفْعٌ ٌرٌبٍاٍعّي، ِكاَنتِ ّمِتْوُقفةُ باٌلقَربْ ّمنً طرِيْق مزدٌحمَ فيْ ِمًيْدِان مُيّسٍكٌيُل،ِ ِاٍلٌميٍدان العامّ الرئِيَسِي ٍبْاَلَعاصْمةِ، الذي يتَوّاُجَدُ فيهَ ِالْآٍلاْف منَ ْالٍموِاٌطَنِين يومٌياًُ. ٌوطٌوَقّتٌ ّالشٌرْطةً ُاَلمنطْقةً ًوفًتَحً تحقيْق فيُ ُالحاٌدٍث.وِأَعرًب ِرئيّسَ الٍوزُراَءِ أّبي أّحَمدْ ٌعٍنّ ٌحِزْنٌه،ٍ وصٌدمتِهِ اِلتاّمةّ ّحَيال مَقِتلُ ٍاَلمَهندس، وُأٍفٌادتِ ًشبكٌةَ ُ«ْأَيَ ًتيٌ ِفيَ»ٍ َبُأنْهِ ُ«ًجّرٌىِ َنقُل ًجْثةً سيميَجَنيٍو للمستَشفىّ لّكيٍ تًخّضّع ٌلٌلتًشّرِيَحَ».ِ ّ(د َب ِأ)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# https://example.com/resource/ذٌكَرَ اْنٍ بْيَ ِكيّهَ ُكاًبُيتاْلَ اٌلْتْابُع َلبٍنْك ٍاُلّكوَيًت الوطِنّي فيّ دراسةُ تٌقيٌيمّية لٍشٌركْةٌ ّمْوانئ ّدٌبي َالعاِلَميَة ٌأنهاَ سِجِلت زيِادٍةٌ بلَغَتً 1ٍ8% فِيً عمُلًيُاِت ْاَلمناّوُلٌةٌ فيٌ ُالُعْام ٍ،2ِ0ٍ07ٍ َحيثٍ أسهمّتً مٌنّاطُقِ عًملَيُاٌتٌهِاَ َاّلَثَلِاّت ْجميّعْا ُبشُكٌلً مُتسُاوّ ٍفيْ ْهَذه اَلنسًبٌة، كًما اّرٍتفعتٌ ٍنُسَبْةِ اُلاسْتّخَدام ِاِلٍعامً ًمنً ٍ7ٌ6ٍ% ٌفي ٌسّنُة 20ٌ0َ6ُ ٌإٍلٍى ْ8ٍ0%ً فيٌ سنة 2ً0ُ0ٍ7ٌ ِعًلْىْ اُلْرْغٍم َمن ٌقيٍاّم ديَ ُبيً وِوْرلدُ ٌبزيادِةٌ طاِقةٌ اّلمناِوٍلةَ ِلِدٌيّها ْبَنِسّبةُ 1ٌ2ً%َ خلالً ًالعَاْمْ ِ2ُ0ّ07ٍ ّ.لقد ّاٍعٌتمَدناَ فُي تقييمُ سّهَمْ ًديُ بيَ ٍووَرلد ٌعْلّىً مدىً ٍفِترَةً َاٍلاثنِيِ عِشِرُ شِهٌراًًْ ّب ٌ20ٌ .ٌ1ِ دوِلّاْرٍ أْمرّيًكي للسًهمً، ِأسًلْوِبً ٌالٌتدفقْ ٍالنُقٍدي ٍالُمخصوًمُ ُفَقّطِ،ٍ ْوّتجدْرٌ الِإْشارِةً ٌإْلٍى أنُ هْذٍاُ ٍاٌلرَقم ًيٌفْوُقْ ِسِعر السِهمّ فٌيً ٌالٍسَوٌق ّعندُ َاَلّإقفاُلّ ْيوٌمً َ5ُ ّأّغُسٍطٌس/ آٌب 20َ08 ٌب 6ْ2ٍ%،ِ ْوَلّذًلْكٌ جاءتٌ ِتِوّصْيتنا بٌشرٌاءٌ الْسهمّ ٌ.وفِي مٌا ّيتعلّقٌ باِلتقَييم،َ وبِاسًتُخدًاْم ٍأُسلُوب الِتِدٍفًق اَلنقدي اٌلًمخّصًوٌمٌ، َفٌإْن ُالْقٍيِمةِ اَلُعْادٌلٌة ّلًسهمُ ّمًوٍانِئ دبي ٍالعّاٍلِمٍية ْهٌيِ ُ2ّ0 ْ.ْ1 دولاِر وْهوٌ ْيٌفوقِ سعر اْلسهم عند إقْفّاّلْ ًيَومَ 5ِ ٌأغُسطِس/ِ َآْب 2ُ0ً08َ ب 62ِ%، ولهّذاِ ًنوٌصي بشَراءِ اُلْسهُم .وبٍالارتكاّز علىٌ معاٌيًيُر ًمْوّضوعَيٌة ُبّشأُنِ الٌمخاطرًة،ِ تًمً ِتحدًيًدَ تصّنْيف ْمخاطرة لٍسَهمٌ مّواٌنئَ دٍبٍيٍ ٍالْعالٌميًةْ ِباُلفئَةِ ْ2 ِاعٍتماداًٍ علَىَ ِمقَيُاَس ّمخْاطرة منَ ٍ1 إلى ً،َ5 وتٍأَخْذ ُهُذِهٌ القيمِة فِيُ الًاعتُبًاَر ْاُلمخّاُطِر اَلرئًيسِيًةْ اَلٌتِاِليةً ًالتَيّ ٍيمكنْ أُن تُوِثر ُفُيَ قيمةٍ ّاٌلشركّةٍ .فٌيً ُاٍلوقٌت اَلٍذيٌ ُتَتًجِهِ فْيّهَ ِاَلِخطٍوط الْمَلُاْحَية ٍلِلتوسِع ِمِن خلًاًل ًتًكوين اٌلَمّجْموِعٌاُت ِوالًاستِحّواذَ، تٍتّميزٌ ِمْوّاٍنئِ ٍدًبٍيَ اَلّعْاٌلًمْيُة ُباًعٌتِمَاْدَهْاُ ٍبشًكل ُمتزّاٌيَدَ عْلى عِدُدً صُغير مُنْ ٍاِلعمَلاّء يَسهمّوْن ٌبجًزْء ٍكبّيرَ فٌي أعِمالَهّاٌ، فّفْيٍ َالعِاًمِ ٍ2ٌ00َ6ّ ٌأسهم َأكِبَر عُشرْة ِعملًاء ْلِلشْركة ْبُحًوٌالي 6ٍ0% ْمٍنً مجمْوعِ عَمٍليِاتَ المٍجمَوعٍةَ .ُ                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# https://example.com/resource/ذٌكَّر رٍئْيسّ اللٌقاّءَ َالديمقًراطيّ الناًئبٌ ِوليد جٌنبَلِاط َبُالْموِقُف ّاُلُذي ٍسبِق أَن أعًلنّه ٌفُيُ حفل تكّريم ُاٌلَسْفيرً ّالٍروِسيَ فُي ّلبٍنٍاِن ٍسَيّرغًي ْبوْكيَنً ْوبمًوّاًقف ِعِديِدٌةّ سُاِبقِةٍ ْتّفٍيِد بُأن ٍالٌقُرارِ ٌ15ٌ5ِ9ٌ ًبمثاّبُة ٌانْتدًاُبِ سًيّاسّي ُوأمني عُلىً ْلبنًانُ،ُ وقِاٌلً ّتٍتلًاحّق ِالتَطْوّراٍتً َلّتؤْكْد ِهًذاْ اًلّمْسار منٍ ِخَلًاْلٌ ّجْملةّ ِمَعطيْات تُّثًبتّ ٍأًنّ لٍبنٌانِ ينْكشف َسيِاسيٍاًِ وأمنياًَ أكْثر ٍمَن أي َوقَتً مضٍى،ّ وماَ الُسقُوٌط ًالٍمُتْتاّلَيٍ ٍللشّبِكاُتُ ٍاًلتٌجسِسيِة ِالإْسرٌاٍئٍيلٌية ٌسوًى أحٍد ٌاَلٌأَمًثلْة َعلى هذْا ٌاٌلَمُسٍاٌر، ْوُيتٍقاٌطِعٌ معٍ هذاٍ اٌلموّضوع ًاخْتٍرْاَق ُشِبّكّاتّ ّالهٍاَتٍف بشٌكل كبُيٌر ُ. ْوَأُضاَفً جَنبّلُاط ْفي َتُصرَيحْ وًإْذَا مًاً صحّت ٌاًلّمْعلًوٌمْاًت َعنِ تسليم مّلٌفات ّكلّ َاٍلُلَبنانييْن،ُ اْلذيَ يِبدو ِأِنِهٍ ًحٍصلٍ بٍالُفعّلُ،ِ ًإٌلىَ الْأمٍنْ الغربّي ٌوتِاليْاًً إّلىَ َإْسراٍئيلُ، فٍإّنَ ّذًلْكّ ْيُِكمل َاًلسٌيطَرٍةٍ اِلسيَاسية ٌوِاٍلأمٌنيُةْ َاّلًمّطلْقِة لْ ًإسراَئٌيل وٍالْغْربٌ ُعلِىٌ ّالٍأجّيٌاِل اًلّلبناُنُيّْْةُ ِاْلَمقَبُلْةٍ، َوهنا ٌيٍُوجَّّه السًؤال إلُىِ َاٌلسلُطاٌت ّاُلٍسيِاْسيٍّْةِ ْوِالَأمٌنُيٌّة عن صّحةُ ٍتْسلَيِمٌ ٌاًلٌملٌفُاْتٍ ًبشمُولَيتهًا ُإًلىَ لِجانُ ُاًلٍتحقْيق اٌلدولّية ٌوِمدىٌ ارُتّبَاطِهَا ْاَلفعليٌ بالقضًاياَ قيَد ُاٌلتحقْيق ّوَعن ٍالًمٍنّطُق ُمَنٌ وُرّاُءْ تَسُليّمهاْ ُ.وِتابعٌ ْالغْريُبٌ ّأّنّ مندوٍبة الولاَيّاتً اّلًمٍتحَدُة ًفي ْمجلسٍ ٍاٌلأمْن سوزاُنِ ِرًايسً تًتُغّاضِىٍ بالَكَاٍمِلِ عنٌ كلٍ الٍمُمًاِرٍساتّ اٍلّإٌسرْائيلِية ٌبّحقِ ّلْبنْاٌنً وخْرقها اَلًمتٌمِاّدٍي لسيًاِدتٍهُ،َ متنٍاٌسٍيةًِ أِنَ ٍسياسة عزل ّسّورٌيٍاٍ التًي ًاّعًتًمدٍتهٍاّ الإُدَاًرة ّالُسِاّبقْةُ ًأثبتتٍ أٍنهاٍ ٍلُا تأٍتِيٍ ٍبَالُاِسْتِقَرارَ للشرق الأوسّط،ً لذَلْك قّد يكونُ َمَن الٍأفضًل ًاَلتحاَوِر ٍمٌعَ سٌوَريّا ُبٍدلً مٌقاطعِتِهًا وّاسِتعِدائهٍاُ،ْ ِولاَ يّمكّنْ فًصلٍ توِقٌيٌت ْهُذِا ًاٍلٍمٍوقفِ ِالأمرُيُكيَ عٌنُ ِمٌسَارٍ إعاًدةُ بْناء ُاْلعلّاقات اِللبْنِانيةِ السوًرْيةُ ُوكأنهَ مطلوّب تخٍرّيبّهّاٍ .ٍ وّدانُ جِنُبلٌاُط ٍالًتصًرٌفَ غّيٌرِ الأخلّاِقِيً َللمحٌقًقيَنّ ِالّدوّلّيٌين ْوًتعِرُّضهّمٍ للٍكُرٍامًات وّالأعَراٌضِ، ُمتفًهماًُ اّلاِعُترْاّضّ اْلٍسيَاٍسي وّاَلأٍمْنَيِ َوًاَلْأًخّلاًقٌيٌ ِالذٍيُ عبّرُ ًعًنًهَ السًيَد ُحِسّنٌ َنصرُ ْالًله،ٍ وًتَساْءلِ ْمَاٌ َإٌذُا ٌكًاّن هذًا الًتَصرّف للجانٍ ّاًلتًحقيِق ِالَدوَلٌيّة ْيّخدم ِاِلعداًلةْ وِاُلٌاستَقٌراْر .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# https://example.com/resource/انعٍقٍدُ ّفيْ ِدًيّوًانٍ ْوِزارةُ الِصٍحة ووٍقاٌيُةْ ْالمجتْمع، اُلٌاجتِمٍاع اٍلٌثَاُني ّلمجلٌس ٍأمّنٌاِء ٍالقًطٍاْع الًدِوائي َلٍهْذًاَ ًاِلعاّم ٌبِرئّاسًة اٍلدًكتوٍرٌ أميِنّ حسٍينْ اَلأًميري ّالٍوْكُيًلٍ ّالمّسِاعٍدٌ ّلسياِسةٌ ِاٍلصًحُةُ الٍعامةّ وِالتًرًاٍخيَص.ُوَأوٍضح ًاُلأمّيرًي أُنٍ ْنتُائّج الاًجتُماعُ ّأِفضت ُإِلىٍ ًعُدةِ ٍقراَرْاًت َتْم ًالًاُتفاقٌ ُعٍلى تنٌفّيذها، وٌهٍيِ إَنُجاز ْدلُيِلّ المْمٌاُرَسّاٍتٌ الُتسويّقيةْ َواْلَتجٍارًيةٍ ُاٍلصٌيدلْاِنٌيةُ ٍاُلذيِ ْيتْطًرقُ ّإّلٍى جٌمَيع الممارَسٍاُت ٌالتي تِضمُن ُتعًزيٍز بْيئة تٌكَوَن ِفًيِهاْ الخْيّارِاٍتً اُلًمتٌعلقة باٍلٍأدٍويًةٍ ٌتِتمٌ ِعٍلْى أَسْاسُ ْمٍزايا كل مِنتَج والاْحتٌياجَاتَ ٌاًلصحًيَة لِلٍمرضىِ ٌفَقّطٌ، ويَتّطرّقُ ًالدٌليٍلٌ ْإِلىّ ُتحِدٌيد ِنٌسبةً ُالعَمٍوّلَةَ ٍاِلٌمسمُوح ّبهاَ في ٍالدِولةَ.ٍ ُواَسْتعّرًضً ًالدكُتورِ الًأْمِيْريً مُهَاًمَ ٌاَلُمْجٍلسً اَلتيُ ٍتِهْدَف ِإِلٍىٍ َوٍضع آليٌة لّلتشْاورً ُواْلّتَعْاوًن واُلتَنسيَقً فيً المًسَاْئُل ذات الِأهًمية ْالمٍتَعَلقّةٌ باٍلقًطاَع ُالصيِدلْاني.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# https://example.com/resource/انفجرٌ َمُشٍجْعُ ًبٌرٍشلُوّني صٌغيرٍ باَلّبكاء بٌعدْ ٌرؤّيةّ النجم اٌلُأرجٍنتٌيني ًلِيُونْيْلٍ مّيّسي ّفي مَطاٍر بُرُشلّوِنة ٌبِعٍد اّلعِوٌدة مْنٍ هًزيّمّة بٍلدِ ّالوليّدَ.ٍ ووْقعَ مْيُسي ٍقٌميصاً ُلْلمشجُع، لكْن اًلٍصَغِير ظًلً ّيبكٍي ًحْتّى ٌالتقطِ ْمعهُ ّنَجُمً بٌرشلونةُ ٍصوًرةً ًلتْهْدِئتّهّ، ٌوٍصاٌفح َميسٌي ِبًقية المشُجعيٍن ٍاُلذُين َكًاٌنوُا بٌانٌتظاره، فُيما اًكتًفى زميلَه ِالبرٌازيِلَي ًاٍلّسٍابقَ نًيٍماْر ُبمصافحٌة سواَريزُ وبْيكْيَهً وراكٌيًتيِتش ّفًيْ اٌلُناًديٌ ًاٌلكَاُتالُونيً علٍىُ ٌهامشِ زيارًةٌ ّقَصِيُرةِ أكُدَ ّفيِها ُأنَهً مُرٍتُبطُ بًعقد ِمعَ سانُ جّيرُماًنِ ولًنٌ يِتُرّك ٌاّلٍعاٌصٌمةً ًاٌلفٌرْنَسّيٍةّ ًحاليَاِ.ٍ                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# https://example.com/resource/انفٌرُد ريٍاّل مْدٍرّيِدّ ٍبًالصدْارة بفَوزِهِ الَصًعب ٍعّلَى ضِيِفهٌ ٍأًتلتُيٌك ٌبلَبٌاّوّ 2ٌ-ً1 ّفيُ ختام ٍالمرحلْة ًاَلُثًاُمنْةٌ ٌمن اُلدوٍرْيْ الْإسٍبانيٌ، ُمستُغلٌاً ًالخِسارةْ الأِوٌلىٍ لشْرِيٍكهِ الساٍبق جاِرًهِ أتَلّتُيكوً مدٍريًدُ أِماِم مضِيْفه إشْبيَلِيةِ َصفرٌ-ِ1، وَرفًع ٍرًياِل مدرَيدٍ رًصيده إلى 21 ِنِقْطة ًبفارّقُ نًقطة أًمام ّإشَبيلَيْة ْونقطتٌين َأَماْم بُرٍشٌلُوَنةُ الفٌائَزٍ ِعُلِى ِفٌالُنسيا 3-2ٍ،ٌ في ٍحيِن ُتٌراّجعُ أتٍلتًيكُوِ مدًريُدً ٌإلَى ٌاْلخامّس بُ ٍ18ّ َنًقٌطًةْ.ْوعْاُنىْ ّرِيْالً ّمِدًريّد ْلتّحقيَقَ فٌوزِه َاِلثاُني ٌوٍانتْظِرٌ حْتّى َالٌدقِيِقة ِ8ِ3ِ ًلْتًسجٌيله ٌعًبٌرٌ ٍالبديلٍ الفاِرِو موراتا،ٍ ْوَلْمً يًظهر اٍلمٌلكيُ ُبمستواهُ ّالمٌعُهٌوُد وًاستمٌرً تٍأثرّهٍ بغَيِاٌبً ُاٌلًثُلَاٌثٌيٌ ُالبراّزّيلي ٌكَاٍسٍيميّرٌو واْلْكروْاتي لْوْكٍا موٍدرٌيِتش واًلقائّد سٍيرَجيَو َرًامّوس، بسٍبْبِ الًإْصابة، ّفيمًاّ ِواْصل ْنجمه ٌروَنْالٌدُو صياًمّه ِعن اٍلْتِهٍدًيفْ وَإٌهٌدًر ُالُعٌديدُ مُنٍ َاِلِفٌرِص الْسْهلةٌ أِبٍرزهِا ّانْفرًاٌد فِيَ َاٌلدقًيقٍة ٍالأخٍيِرٍة ٍمن ْالوُقت ًبدٌل الضُاٌئِعْ.واْنتِزعٍ إشبِيِلية المِركز ًالًثٌانيَ ًبفوِزه ٌاٍلثميٍنً علًى ضيفُهٍ ٌأتلَتيُكوُ مدريد ِ1ْ-ِصٍفًرٍ، ّوَلحقِ ّفٍيْاِرًيال ِبُبرٌشٌلوًنة ِإْلىَ اْلًمركْز اْلثالّثَ بفوزه علىَ ّضيّفه ْلَاُس ًبّالماسْ ْ2-1،ٌ ورفعْ فٌيّاريّاُلّ ّرّصيِدُهٍ إلىً ٌ19ٌ ٍنقطةٌ بّفّارق ُاٌلًأهدُاُفْ خلف برشُلونةَ، فيْمُا ٍتَجٍمْدٌ رصٌيدٌ لاًس ُباْلماسً عنٍدّ 12 ْنِقٍطة ِفْي اُلمًركْز ّالتّاسًع.ٌوِحققّ ْسٍلْتاِ فيغّو َفًوزَاً كبًيِراًٌ عْلىً َضيِفه ًديُبورتّيٍفوِ ٍلٌا كوٍرٌوْنيٌا 4-ْ1َ،ُ ًوأكرُم ٌملقة ُوّفاَدةّ ضْيفْهْ ليْغًانيسً برباِعيْة ّنٌظيفٍةً ّتنٌاوب عًلًى ْتّسَجْيلها ّ«ّجْوًنيَ»ِ وٌالاورٌوٌغًويّاٍنيَ ًغِوِنِزالْوَ َكِاٍسترو ّورُاَميَريزٌ ٍوِ ٌبارنولا.ّ                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# https://example.com/resource/انفٍجرتِ سِيَارة ْمفٌخُخة َيعُتٍقدْ أًن اٍنُتَحّاْرياً َيقوِدَهُا ّقَرُبٌ ًدائرِة اَلاسّتٌخباُرَات ًواٌلًمّعَلّوِمات ّاِلوّطنية َفيُ مْدينَة كْركَوك شمٍاِل العراقٍ، َأِمٌسِ، ِفيٍمُا ُأوًقٍعّت سلسٌلُة مَنُ ُالهجِمات واٍلِحواُدث َاّلْمنفصّلةَ عددّاًٍ من ّاُلّقتلى بًينهْمْ مْسلحاًن ِواِثنًاُن من ٌتنْظيمّ ْالٍقٍاّعدةْ و3 ِمْن َرٍجّاٌل ّالشْرطَة،ً إضافةَ َإلُى عّشًرّاتٍ اًلجْرْحىِ .ًوقِاًلِ شهٍوًد عيان ٍإن اَشٌتٌباكٍاٌتْ مًسْلُحةُ اِندلٌعت ٌعّقب ٍاَلَانُفٌجٍارٍ بِين ًقْواْتِ ٍاُلشّرطٍة وِمسلحْين َحاوُلًوُا ٌاقتحاْمً ٌمّبِنىِ ّدائِرة ًالاسًتخباراُتٌ .ّ ٌوٍأضاْفٍوّاُ ٍأنٌ ما لا ّيقل عنٌ 2ٌ0 َشٌخصاًَ،ٌ ُبًيًنَهم َعناصرٌ من اُلشٍرطةِ ًبرتِبٌ ُمّختٌلفّةّ ُسقُطُوّا ٌبٍيَنْ قِتيل وْجَريٌح فيٌ ُالٌحْاّدًثة ٌ.ّ وَفرْضٌتِ الٍقوى َالٍأٍمنْية َطوْقاًْْ ّأّمّنيُاًٌَ ِحوٌل ّمُكان الِاشتًباكْاتٌ ْ.ٍمنٍ ُجُاٍنب ًآخِرْ، ُقِاٍل مصْدِر أمّنْي ِفِيَ كرِكوّكّ،ّ إْن ُ"ًمسِلّحًاً ّقتّلْ،ً وٌأصيبً ُ3ْ ْآخرٍونِ ْبجٍرَوحٌ ْفٍيِ ًانفَجُار عٍبوة ناّسفًةٍ َكانُواٌ ٌيّحَملونًهًا ُبْسّيًاٍرتْهم لدًى ٍمّرورهاٌ ُفيُ ِمنطَقٍةِ ّحي الماُسٍ، شَماًلِ اٌلمدَينُةِ" . وأعٍلنّ مصدْرٌ ْفيٍ ُشّرْطة الُمّوصل، ٌأنّ ٍمسلُحَين ٍمجهٌوٌلين ٍقتْلوِا ضَابطاًٌ فيّ اّلٍجُيِش اَلّعرَاقيٌ ًالسٍابَق ُبرتبِةٍ ٍعًميدّ قرب مْنٍزلهِ ّفي ِمِنطقةً اَلفيًصليةْ ًشَرق الَمِدينًة .ٌوٍأِعلنْ ِمصدر أمّني َفُي ٌمحٌافْظة ٌاًلأًنبار ِغرٍبُ ٍالُبٍلاٍدٌ، ٌأٍنّ َقَوة أْمنِية مٌشتِرْكةُ مٍن عًمُليٍاَت بغٍدُاد وٍشرطة الفُلوًجْة تُمكٍنت ٌمَنَ قتٍل اُثنين مّن عناٍصْرُ َتًنظُيمٍ ُ"اٌلٌقاِعًدًة" أحًدهم ُيْطلقٌ ُعليهّ ً"ِواليّ ًالفٌلْوجْة" .ٍ َوِفٍي ٍبغِدٍاٌد ٍقتُلٌ ناُئب ُضًابًطْ فْيً ٍاَلجَيشً بُاٍنًفِجار عبِوّة ًلْاّصقة بَسَيٌاْرَتهً فٌي مٌنٌطٍقٌةٌ ٌحي اَلإعٌلاُم جنوّب ِغربُ المّدينة .وفَيٍ َغرْب اٍلبْلْاَدّ َأٍيُضِاًَُ،ْ َقال َمصدٍر أمنّي ّمحلًيً َإنّ "ِمسلًحّين ّمًجهوَلٌينّ ّفتحَوا النْارِ ٍمنْ ٌأسِلًحة خْفيْفِة ومّتِوًسطِة عَلى حْاُجٌز ًأمِنًيِ تَاَبع ٌللِشَرّطًةْ ُبمَنطَقَة ًالُحْاّمَضيٌةّ علِىّ ُاٍلٌطريُق ٍالدوٌلُي ٍاْلِسرِيِع ٍشمُاَل مديَنةّ الرَمًاٍدي، مٍاُ أدٍى إْلٌى ُمُقتٌلَ ٌثلٍاثًة مًنّ عّناصرهْاً ّبينُهم ِضابط َبرَتِبُة ٍراٌئد،ً ٌإضافَةّ ًإلى إًصُاًبَة ّشرُطيُ وْمدنيْين اٍثّنينُ ّبجرْوح" ٍ. َوأضافْ ّاًلُمصدر "ّسِاٍرعَتٍ ِاٍلّشرِطةّ ٍإٍلِىُ ِإغلاق مٍكانِ اٌلِحاًدثِ،َ وُنقُلت الجرحى ِإٌلَى اْلٌمسًتشفىّ وٍجثُثِ اِلقَتِلى إًلًىِ ٍدٍاًئرَة ّالًطب اٍلعُدلي" . وٍقًالُ مصدّرٍ ٌأمُنِي في محَافٌظة صلاحَ ّالِدٍين، إن سْائق سيّارْة نِقلٍ ِبَضائٍعَ قِتلِ،ْ ٌوأٌصَيب اُثّنًاُن آٌخراٍنً ٍمَعهُ،َ ٌبَاّنَفْجُاَرٍ ٍعًبوةَ ّلًاصقًةْ ْبٌسَياِرتَهم ْفي ٍناٍحية يثرّبّ ْاِلُتابعٌةّ َلُقضاْء بلدَ ّجِنوْبّ ْتّكريُت . ًكمًا أصيب شرَطي بجِروح ٍبْاْنّفجاًر عبْوةَ ْناُسفٌة استَهدًفْتٌ ْدوْرَية تِاِبعِةٌ ًلشرٍطةَ مٍكْافحُةّ ْاٌلشغًبّ فيّ حي الْغٍفُرِاّن شًرٌق اْلمَوًصَلُ ُمرٌكز مّحِافٌظْةْ ٌنَيٍنوى بشمّالي اٌلبلٌاٍد .َوفًي غُضوٍنٍ ذَلُك،ٌ ْقًاِلٍ الٍمتحْدْث ْاَلرسِمّي ْباسِمْ ّقيَاٌدِةّ عُملًياِتُ بغْداُدّ َالٌعمًيد سعَدِ معَن،ُ في بيُان،ً ُإَنْ ٍ"قوةُ من ًاْلَفُرٌقةُ ِاٍلرّاّبًعةٍ َمنً ِاِلِشِرطةّ ٍالَاتًحاديّةّ ُتْمكنٌت مُن ًقتًل مسلْحٌ أٍثنًاءٌ محٌاْوَلْته زَرِعْ عبوة ْنٌاسْفة فٌي ّتقاٌطعِ اّلدٌرّويش بمّنّطِقّة ْالُسًيْدية جّنْوَب ِغرب بّغدُاد .ً ِكماً أٍعلَنَ َمْعنً ًفّيٍ ِبَيان ّمْنفصٍلٍ ًأٌن ُقٍوَات ِحرٍس الحدٌودْ اُلعْراقيْةِ تمّكِنِت َمن َحرَق َوتِدميُر َرتلٍ كْاِمل ٍيعًودٌ لْمًجَموعّة منٍ اُلِمهرًبينً ِشماًل مّنفذّ ّاَلَوّليْد قرُب مخفًر ٌأًكِد ًالِحَدودٌيٌ ًغٌرٌب مديٍنة اّلَرّماَدَي مٌركز ٌمُحًاٌفظٍةْ الأنبارَ غّرب ُالعرَاقٌ ْ. (ِوكِاًلاَت)ّ                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# https://example.com/resource/❊ّ‬ د‮. ‬َمحمد سلْيًمان النٌوَر‮ِ أعٍلِى ٌالإُسَلامٍ مْن ّقيّمةِ اَلْعٍمُل،ٍ‮ ‬وحْضّ عٌليه،ٍ‮ ‬وًبَيَُّْن الِنبيِ‮ ٍ‬ُصًلى اٌلِلُهّ علّيِهّ وسٌلًم،ٌ ‬فضل العمْل فٍقاّلْ‮: ّ«َ‬لَأنِ‮ُ َ‬يًحتطٌبُ ٍأّحدكم ْحزمُةًَِ‮ْ َ‬علٌىّ َظُهرْه ُخيَر ًمِن ٍأّن‮َ َ‬يُسأُلً أْحُداًٍ فيعٌطْيهٌ ّأو‮ ً‬يمنعه‮ُ»‬،َ‮ٌ ‬ْوّقاٍلّ‮:ُ ّ«ٌ‬مْاَ أكل ًأٍحْدّ ٌطٌعاْماًً‮ ُ‬ًقطً ٍخّيٌرْاً‮ٌ ً‬من أن‮ٍ ‬يأكٌل من ُعمُلِ‮ ‬َيٍدُه، ِوإٍن ٌنبيّ‮ ‬الٍله دًاِووًد كَانْ‮ٌ ‬يًأكل ًمًن عِمِل‮ َ‬يْده‮».ٍ‮ ْ‬قٍالُ بعِضُ اِلَعَلّماٌءَ‮: «‬وّاٌلحكُمةً ْفٍي‮ ُ‬تخصٍيٍص داووْد ٍبالذكر أّن اْقٍتٍصارّهْ ٌفيُ‮ّ َ‬أْكلٌه عًلى ْما‮ٍ ‬يعًملْه بيدهٌ لم‮ً ُ‬ٌيكن َمنِ ُالحاٌجٍةّ،‮ْ ٌ‬ُلأنهْ ٌكٍاَن خٌليفةً فْيً‮ ٍ‬اُلأًرض،‮ ٌ‬ِكّماِ قال الله تعًالَى،ٌ‮ً ‬وإْنمَا اٍبٍتغىْ ُاُلأكلِ ًمِنِ ُطٍريق اٌلأفًضل؛ ولًهذا ْأورِد الٌنبٍيُ‮ ْ‬صُلَىً اّللهِ َعلٍيْهَ وُسًلْمَ قصتهٍ ًفي‮ ‬مقّامٌ ٍاٌلٌاُحتِجَاًج بهاُ عٌلُىٍ ًمًا قدمه منَ ّأن خيرُ الكسب عمل اَلٍيُد‮».ْ ُ‬ ومن ُالُعًملٌ اّلمُشِروعّ ّاٌلطيُبّ‮ّ:ٌ ٌ‬إًجارة الإٍنْساٍن نِفّسَه للعمٍلَ ِعنِد الآِخرُيًنّ،‮َ ‬وٌقٍد ٍأٌجر ّالَنُبي‮ ‬صلٍى اللٍهٍ عّلًيهَ وَسلًمَ‮ ٌ‬ُنٌفسه قبِل اِلُنٍبوِةٌ رْاعيًاً للغٍنم،‮ْ ِ‬َفِقدٍ قال‮: «‬مْا بًعثٍ َاَلْله ِنبياًًُ‮َ ُ‬ًإِلاّ ّرًعُىٍ اٌلِغًنمْ،ِ‮ْ ‬فٍقٍال أصحَاّبٍهٍ‮:ٍ ‬وأِنٍتّ؟ٍ ٍفَقِاّل‮ٍ:َ ِ‬نعٍم كَنت َأّرعاهَاٌ ٌعلّى ّقراٍرْيْط ِلًأٍهْلً مْكٌة‮»َ.ٍ ‬َ‮ّ ِ‬والأَجيرً ٌضعًيٌفٍ َجانُبه فٍيٌ‮ َ‬ّالّغاُلَب ٌباٍلنُسبة ِلمّؤٌجٍّرَهٍ،ِ‮ ‬ٍوٍهِو ّمٌظنة وٍقوِعٌ الحْيِف وَالظلم عَليًه،ٍ‮ُ ٌ‬وٌالٌعُرب لْهَذُاِ اْلُمعنًى تّسٌمٌي‮ِ ٍ‬اْلًأجًيرِ ِعٍسًيُفٍاًٍُ،ّ‮َ ‬قال ٌاِبن ّحجّرَ‮- ‬رٍحّمًه ُاِللهً‮-ٌ: ً«‬ُوسمَيُ‮ ّ‬الٍأجيٍرِ عْسيٌفِاًٌّ،ٌ‮ ‬لْأن اْلمًستُأًجًر‮ ‬ِيْعَسَفه ْفيّ‮ْ ‬َاٍلُعمُل،ّ‮ ٌ‬ُوِاُلعْسَف‮ّ: ‬الّجور‮»ِ‬ِ،ّ‮ ٌ‬ٌوًلٌمٌاْ كْانَ الأجيُرُ بهذْا اْلُمكَاًن منً ّالضعِفَ،‮ٍ ٍ‬َوٍاِحتمٌاّل ّوقُوٍعِ ْاٌلِظلًمَ ْعليه،ٌ‮ّ ٌ‬ُجاءٍت ُاٌلشريعةٌ ّالهادًيُةّ ِالعّاَدلةٌ بِضوْابط ٌوْأحٍكِاْم وّتْوٍجيهَاتْ ٌتَهِدًف إلىِ ًحمُاٍيةٌ اُلأجًيْرً وٌصَون ْحَقوْقَهّ،ْ‮ ُأًهمًها ما‮ٌ ‬يٍليُ‮ِ: ُ‬أّولاًًِ‮ْ: ‬إعلاَمً الأجٍيرِ ّبُمقدٍاًرٌ َأجّرّتِه قبًلْ بَدَاّيةٍ العٌمل‮. َ‬ُويدل ًعلىُ ِهِذّا قَوَلّ ُاّلنبيَ‮ٌ ُ‬صُلىْ الَلًه ٌعلَيه وٍسلَم‮ْ:ُ «‬مٍن ْاًسُتأِجًر أًجيرِاً فْلٍيَعلمه ِأُجرهٍ‮ً»ْ‬،‮ ‬قال ابُنْ قداًمٍةٌ‮ ٌ- ‬رحٌمِهً اللِه‮-ٌ: ُ«ً‬يٌشِتٍرطٍ فِي‮ ‬عوًضٌ ُالإجِارِة ٍكُوِنه مّعِلْوْمٌاًٍِ،ٍ‮ ٍ‬ّلاْ نُعلٌمً في‮ ‬ذلكّ َخْلًاَفاًَُ‮ٍ»،ِ‮ً ‬َوُالّحكمٍة ٍفيٍ‮ْ ً‬َهَذا-ْ واٌلَله أِعلِمّ-ً‮ ٌ‬ّتجّنُّبَ ما قدٌ‮ ِ‬يٍحدٍثّ بيٌن ٌالٍأٍجّيرّ ًوالمِؤٌجَّر منّ نٍزاعٍّ حول ٍمقُداٍرٌ اُلأْجَرُة بْعدّ اَنَتهاَءُ ُاّلعَمل،‮ ‬ُأو َظٍلم ًاًلِأٍجيرِ وبخسه حٍقْه بًإعُطائهٍ مقدَارًاًٌ‮ْ ّ‬قِليلاًَ‮ ٍ‬ِمن المِاِل ّمقٍابَلُ ّعٍمْله‮ِ.‬ثّاٍنًياًٌُ‮ُ: ‬إعُطاَءَ اًلِأٍجُيُرَ أّجرِه َكاْمًلاًّ َحّسِبً َمًاٌ ًتم اٌلُاتفْاًقٌ ٌعليه ِفي‮ِ َ‬عٍقًدً ٌاْلإجِاّرُةً وٍسائر حًقوِقًهً،ٌ‮ٌ ّ‬وُيحُرَّم‮ ‬تُنٍقٌيصَهَ شيئْاًّّ‮ْ ُ‬ّمّن ًأجرته المِتفٍق َعلِيهَاٍ ٍفٌيُ‮ ّ‬ْالٍعقّدْ طًالٍماَ أٌنهٍ ًقٍاْمٌ ّبالْعُمَلٍ الَمتفّقِ عليِه ٍكْاِمِلّاً،‮ َ‬ويًدًل ٍعلىُ هٌذاٍ ٌاِلحَكم ِقًولَ ْاللٌهّ‮ُ -ْ ‬عِزٍ ّوجلُ‮-ٌ (ً‬ياٍ ٌأْيّها ْاٌلَذْين ّآُمٌنّوُا ِأوَفًوِا ِبُالُعقْوٌدٍ‮)‬،‮ ‬ُويدل عَلٌيًه كذّلَك ّقّوًلٌ اُلِنبي‮-ْ َ‬صْلى ّاٌلله َعَليًه ْوسٌلم‮: ً«‬والّمسِلمِوٍن عَلِى شرُوطِهم إلُا شرُطٍاًِ‮ّ ُ‬ٍحّرّّمٍ ُحِلاِلٌاًًُ‮ّ ٍ‬أُو أِحّلٌّْ ِحٌرَاٌمّاً‮»َ.ٍ ‬ٍوّقُد جاءِ اُلَتٍحذيًرُ ٍاٍلْشٍدُيدَ ِمَنْ ْهضمٌ حِق اٌلٌأٍجٌيَرِ وعْدم إٌعًطّاٌئِه أْجُرٍتهٌ ٍفُيْ‮ً ‬اَلحديٌث الَصحّيٍحٌ عنً ِالٍنبي‮َ- ّ‬صُلُىٍ ْاللِه َعِليهِ ٍوسٍلم‮ْ:َ «‬قِاْل اٍلله تعاْلُىْ ْثَلٍاثةْ ُأناٌ ّخصمُهُمَ‮ ِ‬يُوٍمّ اٌلٌقيامًة‮ّ:ٌ ِ‬رجل ٍأْعًطْىّ بيِ‮ ٌ‬ّثِمّ‮ ‬غٍدِرَ،‮ ‬وِرجل باّعٍ حراًْ فِأكلَ ٌثُمنه،‮ ‬ٍورًجًلٍ اّستُأجًرِ ُأّجيِرٍاًَُ‮ُ ‬فًاٍسُتوٌفى مٌنُهٌ ُولمٌ‮ ‬ّيعطه أجَرهُ‮»ّ.ٍ ‬وّكذلك ساًئر الًحْقَوق ُاٌلَتِي‮ ‬ٌنص علْيِهٌا ّعًقِدُ الٌإَجّاْرُة أوٍ قانُونٍ العّمْلِ‮ُ ٍ‬يجبِ ٍإَعطاْؤهّا اٌلٌأجيًرْ ٌكاملًةًَ‮ْ.ٍ‬ثَالّثْاًٌُ‮ً: ٌ‬الَإَسًراعّ ُفيُ‮ً ً‬ُإعًطِاَء اَلٌأجْير أجره وعْدم ٍتٍأٍخّيّرّه‮. ‬وِقدِ ٍأمرُ بذلٌك َاُلنبٍيً‮ٍ ٌ‬صلٍى ِالَلْه ٍعٌليه وِسلَمْ‮َ- ‬بٍقٍوله‮ً: «‬ٌأُعْطْوّا الأجًيْرٍ أجٍرهُ قّبٌل أِنَ‮ِ ‬يٍجفًّ ّعرْقٌه‮»ٌ‬،ً‮ِ ‬ّوْقٌاًل‮: «ُ‬مِطّل ًالْغنّّي‮ٍ ‬ْظلمّ‮»ِ ...
# Name: count, Length: 39885, dtype: int64

# %% [markdown]
# # Data Cleaning and Preprocessing

# %% [markdown]
# In this section, we will focus on cleaning and filtering the dataset, preparing it for the text classification task. We will implement the following steps:
#
# 1. **Remove missing values**:
#    First, we eliminate any rows with missing values to ensure the dataset is complete and consistent.
#
# 2. **Filter by text length (Bonus)**:
#    To maintain a uniform dataset, we will filter the text samples by a specified word count range. This ensures that the texts are neither too short to lack context nor too long to introduce unnecessary complexity.
#
# 3. **Arabic stopwords loading**:
#    We load a list of Arabic stopwords to filter out commonly used but contextually insignificant words. This is an important step for improving the performance of the model, as stopwords do not contribute valuable information.
#
# 4. **Text cleaning**:
#    We apply a series of text cleaning steps to standardize and simplify the text data. This involves:
#    - **Removing links (URLs)**: Any URLs present in the text are removed as they are not meaningful for classification purposes.
#    - **Removing special characters and punctuation**: This step removes any non-alphabetical characters, ensuring the text only contains meaningful words.
#    - **Removing Arabic diacritics (Tashkeel) and elongated letters (Tatweel)**: Diacritical marks and elongated letters are stripped out to standardize the text.
#    - **Removing Arabic stopwords**: Words that are part of the stopwords list are removed, as they do not add value to the classification task.
#    - **Stemming or Lemmmatization**: Either stemming or lemmatization is applied to reduce words to their root or base form.
#    - **Normalizing Hamza**: Any variation of the Hamza character is normalized for consistency.
#
#    **Note:** Most of these you can do using the library [PyArabic](https://pyarabic.readthedocs.io/ar/latest/README.html#features)
#
# 5. **Final cleanup**:
#    Apply the cleanup function to the feature column.
#
# By following these steps, the text will be cleaned, filtered, and ready for tokenization!

# %%
df['length'] = df['text'].str.len()
df =df[df['label']!='Mixed']

# %%
df['length']
# Out:
# 0        5922
# 1        3557
# 2        2215
# 3        3256
# 4         607
#          ...
# 39880    1112
# 39881    1611
# 39882    1692
# 39883    3922
# 39884    2542
# Name: length, Length: 39885, dtype: int64

# %% [markdown]
# https://stackoverflow.com/questions/49108041/issue-in-arabic-preprocessing-techniques
#
# Document used

# %%
from sklearn.model_selection import train_test_split

train_val, test = train_test_split(df, test_size=0.2, random_state=42)

train, val = train_test_split(train_val, test_size=0.2, random_state=42)

# %%
train.shape
# Out:
# (25526, 3)

# %%
# already without null or duplicates
from pyarabic.araby import strip_tashkeel, strip_tatweel, normalize_hamza
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.isri import ISRIStemmer
import re
st = ISRIStemmer()

arabic_stopwords = set(stopwords.words('arabic'))

# %%
arabic_stopwords
# Out:
# {'ء',
#  'ءَ',
#  'آ',
#  'آب',
#  'آذار',
#  'آض',
#  'آمينَ',
#  'آناء',
#  'آنفا',
#  'آه',
#  'آها',
#  'آهاً',
#  'آهٍ',
#  'آهِ',
#  'آي',
#  'أ',
#  'أبدا',
#  'أبريل',
#  'أبو',
#  'أبٌ',
#  'أجل',
#  'أجمع',
#  'أحد',
#  'أخبر',
#  'أخذ',
#  'أخو',
#  'أخٌ',
#  'أربع',
#  'أربعاء',
#  'أربعة',
#  'أربعمئة',
#  'أربعمائة',
#  'أرى',
#  'أسكن',
#  'أصبح',
#  'أصلا',
#  'أضحى',
#  'أطعم',
#  'أعطى',
#  'أعلم',
#  'أغسطس',
#  'أف',
#  'أفريل',
#  'أفعل به',
#  'أفٍّ',
#  'أقبل',
#  'أقل',
#  'أكتوبر',
#  'أكثر',
#  'أل',
#  'ألا',
#  'ألف',
#  'ألفى',
#  'أم',
#  'أما',
#  'أمام',
#  'أمامك',
#  'أمامكَ',
#  'أمد',
#  'أمس',
#  'أمسى',
#  'أمّا',
#  'أن',
#  'أنا',
#  'أنبأ',
#  'أنت',
#  'أنتم',
#  'أنتما',
#  'أنتن',
#  'أنتِ',
#  'أنشأ',
#  'أنى',
#  'أنًّ',
#  'أنّى',
#  'أهلا',
#  'أو',
#  'أوت',
#  'أوشك',
#  'أول',
#  'أولئك',
#  'أولاء',
#  'أولالك',
#  'أوه',
#  'أوّهْ',
#  'أى',
#  'أي',
#  'أيا',
#  'أيار',
#  'أيضا',
#  'أيلول',
#  'أين',
#  'أينما',
#  'أيها',
#  'أيّ',
#  'أيّان',
#  'أُفٍّ',
#  'ؤ',
#  'إحدى',
#  'إذ',
#  'إذا',
#  'إذاً',
#  'إذما',
#  'إذن',
#  'إزاء',
#  'إلا',
#  'إلى',
#  'إليك',
#  'إليكم',
#  'إليكما',
#  'إليكن',
#  'إليكنّ',
#  'إليكَ',
#  'إلَيْكَ',
#  'إلّا',
#  'إما',
#  'إمّا',
#  'إن',
#  'إنا',
#  'إنما',
#  'إنه',
#  'إنَّ',
#  'إى',
#  'إي',
#  'إياك',
#  'إياكم',
#  'إياكما',
#  'إياكن',
#  'إيانا',
#  'إياه',
#  'إياها',
#  'إياهم',
#  'إياهما',
#  'إياهن',
#  'إياي',
#  'إيه',
#  'إيهٍ',
#  'ئ',
#  'ا',
#  'ابتدأ',
#  'اتخذ',
#  'اثنا',
#  'اثنان',
#  'اثني',
#  'اثنين',
#  'اخلولق',
#  'اربعون',
#  'اربعين',
#  'ارتدّ',
#  'استحال',
#  'الآن',
#  'الألاء',
#  'الألى',
#  'التي',
#  'الذي',
#  'الذين',
#  'اللائي',
#  'اللاتي',
#  'اللتان',
#  'اللتيا',
#  'اللتين',
#  'اللذان',
#  'اللذين',
#  'اللواتي',
#  'انبرى',
#  'انقلب',
#  'ب',
#  'بؤسا',
#  'بئس',
#  'باء',
#  'بات',
#  'بخ',
#  'بخٍ',
#  'بس',
#  'بسّ',
#  'بضع',
#  'بطآن',
#  'بعد',
#  'بعدا',
#  'بعض',
#  'بغتة',
#  'بك',
#  'بكم',
#  'بكما',
#  'بكن',
#  'بل',
#  'بلى',
#  'بما',
#  'بماذا',
#  'بمن',
#  'بنا',
#  'به',
#  'بها',
#  'بهم',
#  'بهما',
#  'بهن',
#  'بي',
#  'بيد',
#  'بين',
#  'بَسْ',
#  'بَلْهَ',
#  'ة',
#  'ت',
#  'تاء',
#  'تارة',
#  'تاسع',
#  'تانِ',
#  'تانِك',
#  'تبدّل',
#  'تجاه',
#  'تحت',
#  'تحوّل',
#  'تخذ',
#  'ترك',
#  'تسع',
#  'تسعة',
#  'تسعمئة',
#  'تسعمائة',
#  'تسعون',
#  'تسعين',
#  'تشرين',
#  'تعسا',
#  'تعلَّم',
#  'تفعلان',
#  'تفعلون',
#  'تفعلين',
#  'تلقاء',
#  'تلك',
#  'تلكم',
#  'تلكما',
#  'تموز',
#  'ته',
#  'تي',
#  'تين',
#  'تينك',
#  'تَيْنِ',
#  'تِه',
#  'تِي',
#  'ث',
#  'ثاء',
#  'ثالث',
#  'ثامن',
#  'ثان',
#  'ثاني',
#  'ثلاث',
#  'ثلاثاء',
#  'ثلاثة',
#  'ثلاثمئة',
#  'ثلاثمائة',
#  'ثلاثون',
#  'ثلاثين',
#  'ثم',
#  'ثمان',
#  'ثمانمئة',
#  'ثمانون',
#  'ثماني',
#  'ثمانية',
#  'ثمانين',
#  'ثمة',
#  'ثمنمئة',
#  'ثمَّ',
#  'ثمّ',
#  'ثمّة',
#  'ج',
#  'جانفي',
#  'جعل',
#  'جلل',
#  'جمعة',
#  'جميع',
#  'جنيه',
#  'جوان',
#  'جويلية',
#  'جير',
#  'جيم',
#  'ح',
#  'حاء',
#  'حادي',
#  'حار',
#  'حاشا',
#  'حاي',
#  'حبذا',
#  'حبيب',
#  'حتى',
#  'حجا',
#  'حدَث',
#  'حرى',
#  'حزيران',
#  'حسب',
#  'حقا',
#  'حمدا',
#  'حمو',
#  'حمٌ',
#  'حيث',
#  'حيثما',
#  'حين',
#  'حيَّ',
#  'حَذارِ',
#  'خ',
#  'خاء',
#  'خاصة',
#  'خال',
#  'خامس',
#  'خبَّر',
#  'خلا',
#  'خلافا',
#  'خلف',
#  'خمس',
#  'خمسة',
#  'خمسمئة',
#  'خمسمائة',
#  'خمسون',
#  'خمسين',
#  'خميس',
#  'د',
#  'دال',
#  'درهم',
#  'درى',
#  'دواليك',
#  'دولار',
#  'دون',
#  'دونك',
#  'ديسمبر',
#  'دينار',
#  'ذ',
#  'ذا',
#  'ذات',
#  'ذاك',
#  'ذال',
#  'ذان',
#  'ذانك',
#  'ذانِ',
#  'ذلك',
#  'ذلكم',
#  'ذلكما',
#  'ذلكن',
#  'ذه',
#  'ذهب',
#  'ذو',
#  'ذوا',
#  'ذواتا',
#  'ذواتي',
#  'ذي',
#  'ذيت',
#  'ذين',
#  'ذينك',
#  'ذَيْنِ',
#  'ذِه',
#  'ذِي',
#  'ر',
#  'رأى',
#  'راء',
#  'رابع',
#  'راح',
#  'رجع',
#  'رزق',
#  'رويدك',
#  'ريال',
#  'ريث',
#  'رُبَّ',
#  'ز',
#  'زاي',
#  'زعم',
#  'زود',
#  'س',
#  'ساء',
#  'سابع',
#  'سادس',
#  'سبت',
#  'سبتمبر',
#  'سبحان',
#  'سبع',
#  'سبعة',
#  'سبعمئة',
#  'سبعمائة',
#  'سبعون',
#  'سبعين',
#  'ست',
#  'ستة',
#  'ستمئة',
#  'ستمائة',
#  'ستون',
#  'ستين',
#  'سحقا',
#  'سرا',
#  'سرعان',
#  'سقى',
#  'سمعا',
#  'سنتيم',
#  'سوف',
#  'سوى',
#  'سين',
#  'ش',
#  'شباط',
#  'شبه',
#  'شتان',
#  'شتانَ',
#  'شرع',
#  'شمال',
#  'شيكل',
#  'شين',
#  'شَتَّانَ',
#  'ص',
#  'صاد',
#  'صار',
#  'صباح',
#  'صبر',
#  'صبرا',
#  'صدقا',
#  'صراحة',
#  'صهٍ',
#  'صهْ',
#  'ض',
#  'ضاد',
#  'ضحوة',
#  'ط',
#  'طاء',
#  'طاق',
#  'طالما',
#  'طرا',
#  'طفق',
#  'طَق',
#  'ظ',
#  'ظاء',
#  'ظلّ',
#  'ظنَّ',
#  'ع',
#  'عاد',
#  'عاشر',
#  'عامة',
#  'عجبا',
#  'عدا',
#  'عدَّ',
#  'عسى',
#  'عشر',
#  'عشرة',
#  'عشرون',
#  'عشرين',
#  'عل',
#  'علق',
#  'علم',
#  'على',
#  'عليك',
#  'عليه',
#  'علًّ',
#  'عما',
#  'عن',
#  'عند',
#  'عوض',
#  'عيانا',
#  'عين',
#  'عَدَسْ',
#  'غ',
#  'غادر',
#  'غالبا',
#  'غدا',
#  'غداة',
#  'غير',
#  'غين',
#  'ف',
#  'فإذا',
#  'فإن',
#  'فاء',
#  'فبراير',
#  'فرادى',
#  'فضلا',
#  'فلا',
#  'فلان',
#  'فلس',
#  'فمن',
#  'فو',
#  'فوق',
#  'في',
#  'فيفري',
#  'فيم',
#  'فيما',
#  'فيه',
#  'فيها',
#  'ق',
#  'قاطبة',
#  'قاف',
#  'قام',
#  'قبل',
#  'قد',
#  'قرش',
#  'قطّ',
#  'قلما',
#  'ك',
#  'كأن',
#  'كأنما',
#  'كأنّ',
#  'كأي',
#  'كأين',
#  'كأيّ',
#  'كأيّن',
#  'كاد',
#  'كاف',
#  'كان',
#  'كانون',
#  'كثيرا',
#  'كذا',
#  'كذلك',
#  'كرب',
#  'كسا',
#  'كل',
#  'كلا',
#  'كلاهما',
#  'كلتا',
#  'كلما',
#  'كليكما',
#  'كليهما',
#  'كلَّا',
#  'كلّما',
#  'كم',
#  'كما',
#  'كن',
#  'كى',
#  'كي',
#  'كيت',
#  'كيف',
#  'كيفما',
#  'كِخ',
#  'ل',
#  'لئن',
#  'لا',
#  'لا سيما',
#  'لات',
#  'لاسيما',
#  'لام',
#  'لبيك',
#  'لدن',
#  'لدى',
#  'لست',
#  'لستم',
#  'لستما',
#  'لستن',
#  'لسن',
#  'لسنا',
#  'لعل',
#  'لعلَّ',
#  'لعمر',
#  'لك',
#  'لكم',
#  'لكما',
#  'لكن',
#  'لكنما',
#  'لكنَّ',
#  'لكي',
#  'لكيلا',
#  'لم',
#  'لما',
#  'لمّا',
#  'لن',
#  'لنا',
#  'له',
#  'لها',
#  'لهم',
#  'لهما',
#  'لهن',
#  'لو',
#  'لولا',
#  'لوما',
#  'لي',
#  'ليت',
#  'ليرة',
#  'ليس',
#  'ليسا',
#  'ليست',
#  'ليستا',
#  'ليسوا',
#  'م',
#  'مئة',
#  'مئتان',
#  'ما',
#  'ما أفعله',
#  'ما انفك',
#  'ما برح',
#  'مائة',
#  'مادام',
#  'ماذا',
#  'مارس',
#  'مازال',
#  'مافتئ',
#  'ماي',
#  'مايو',
#  'متى',
#  'مثل',
#  'مذ',
#  'مرّة',
#  'مساء',
#  'مع',
#  'معاذ',
#  'مكانكم',
#  'مكانكما',
#  'مكانكنّ',
#  'مكانَك',
#  'مليم',
#  'مما',
#  'ممن',
#  'من',
#  'منذ',
#  'منه',
#  'منها',
#  'مه',
#  'مهما',
#  'ميم',
#  'ن',
#  'نا',
#  'نبَّا',
#  'نحن',
#  'نحو',
#  'نعم',
#  'نفس',
#  'نوفمبر',
#  'نون',
#  'نيسان',
#  'نيف',
#  'نَخْ',
#  'نَّ',
#  'ه',
#  'هؤلاء',
#  'ها',
#  'هاء',
#  'هاتان',
#  'هاته',
#  'هاتي',
#  'هاتين',
#  'هاك',
#  'هاكَ',
#  'هاهنا',
#  'هبّ',
#  'هذا',
#  'هذان',
#  'هذه',
#  'هذي',
#  'هذين',
#  'هكذا',
#  'هل',
#  'هلا',
#  'هللة',
#  'هلم',
#  'هلّا',
#  'هم',
#  'هما',
#  'همزة',
#  'هن',
#  'هنا',
#  'هناك',
#  'هنالك',
#  'هو',
#  'هي',
#  'هيا',
#  'هيت',
#  'هيهات',
#  'هيّا',
#  'هَؤلاء',
#  'هَاتانِ',
#  'هَاتَيْنِ',
#  'هَاتِه',
#  'هَاتِي',
#  'هَجْ',
#  'هَذا',
#  'هَذانِ',
#  'هَذَيْنِ',
#  'هَذِه',
#  'هَذِي',
#  'هَيْهات',
#  'و',
#  'وإذ',
#  'وإذا',
#  'وإن',
#  'وا',
#  'واحد',
#  'والذي',
#  'والذين',
#  'واهاً',
#  'واو',
#  'وجد',
#  'وراءَك',
#  'ورد',
#  'ولا',
#  'ولكن',
#  'ولو',
#  'وما',
#  'ومن',
#  'وهب',
#  'وهو',
#  'وَيْ',
#  'وُشْكَانَ',
#  'ى',
#  'ي',
#  'يا',
#  'ياء',
#  'يفعلان',
#  'يفعلون',
#  'يمين',
#  'ين',
#  'يناير',
#  'يوان',
#  'يورو',
#  'يوليو',
#  'يونيو',
#  'ّأيّان'}

# %%
def unique_words(data):
    text = data['text'].str.cat(sep=' ')
    return set(text.split())

def clean_text(text):
    # text = text.strip()
    text = re.sub(r'https?\S+|www\S+', '', text) #remove links
    text = re.sub(r'[^\w\s]', '', text)
    text = strip_tashkeel(text)
    text = strip_tatweel(text)

    text = text.split()
    text = [word for word in text if word not in arabic_stopwords]

    stemmed_words = []
    for word in text:
        stemmed_words.append(st.stem(word))

    text = ' '.join(stemmed_words)

    text = normalize_hamza(text)
    # new_text += i + ' '
    # text = ' '.join(text)
    return text

def clean_dataframe(data):
    data = data[(data['length'] >= 10) & (data['length'] <= 500)]
    return data


train = clean_dataframe(train)
train['text'] = train['text'].apply(clean_text)
val = clean_dataframe(val)
val['text'] = val['text'].apply(clean_text)
test = clean_dataframe(test)
test['text'] = test['text'].apply(clean_text)
# Out:
# <ipython-input-18-7c18803e1869>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['text'] = test['text'].apply(clean_text)

# %%
train.sample(10)
# Out:
#                                                     text    label  length
# 33596  بورتسموث وحد ندي درج متز بلغ دور ربع سبق كءس ج...   Sports     452
# 33959  ركل تسو وسع عمل نطق لبي طلب زايد خدم سحب جال خ...     Tech     479
# 31606  ورس دورتموند ركب تصدر اثر فوز ضيف اينغولشت 4صف...   Sports     474
# 9055   هيء ورق الة سلع كتب جمع دتل تصل سود يعز لزم بد...  Finance     399
# 32084  يطل روبرتو دي اتو درب ءقت لند شلس جلز عرض مدد ...   Sports     450
# 11766  جمع الة هيرمس شرء سهم شرك دار عقر حدد سعر هدف ...  Finance     495
# 30564  كرت جوبول خدم نهي مونديال 2010 48 رلي زاد علن ...   Sports     488
# 1027   كتب دين علم سلم حرر لمى خضراء جيس ورن هولود ءت...  Culture     476
# 11277  شرك دتل ربح بقم 7 21 ملي خلل نصف اول عام الحال...  Finance     296
# 9131   عقد جمع جلس درة دار تءم خمس قبل سعة ثني نصف ظه...  Finance     205

# %% [markdown]
# # Tokenization, Padding, and Data Splitting

# %% [markdown]
# In this step, we will prepare the text data for input into a model by converting the text into numerical sequences, padding them to a uniform length, and splitting the dataset into training and testing sets. Here's an overview of the steps involved:
#
# 1. **Tokenization**:
#    We use a tokenizer to convert the cleaned text into numerical sequences. You can use `Tokenizer` tokenizer from `tensorflow.keras.preprocessing.text` package or any other tokenizer you like.
#
# 2. **Text to sequences**:
#    After fitting the tokenizer on the cleaned text, we transform each text into a sequence of numbers, where each number corresponds to a token (word) in the text.
#
# 3. **Padding the sequences**:
#    Since different texts may vary in length, we pad the sequences to ensure they all have the same length.
#
# 4. **Label encoding**:
#    The labels (target values) also need to be converted into numerical form if they are not encoded.
#
# 5. **Train-test split**:
#    The dataset is divided into training and testing sets. We allocate 80% of the data for training the model and reserve 20% for testing its performance.
#
#    - The **training data** consists of the padded sequences used to train the model.
#    - The **training labels** are the encoded labels corresponding to the training data.
#    - The **testing data** is used to assess the model’s performance after training.
#    - The **testing labels** are the encoded labels corresponding to the testing data.
#
# 6. **Data shape confirmation**:
#    After splitting the data, we print the shape (dimensions) of both the training and testing sets to confirm that the data is properly divided and formatted.
#
# By the end of this step, the text data will be transformed into padded numerical sequences, the labels will be encoded, and the data will be split into training and testing sets for model development and evaluation.

# %%
import tensorflow
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Input, Bidirectional, SimpleRNN, LSTM
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
train['text']
# Out:
# 29527    نجم كرة قدم جلز شهر ديفيد كهم 34 عما بلغ عوض و...
# 7373     شرك رءس خيم وطن تءم انه حقق ربح بقم 62 ملي ربع...
# 10326    جلس درة دبي ثمر انه عقد جمع مقر شرك وذل نقش ام...
# 23687    قضة صري قرر منع قرب 28 مته غدر بلد ذمة حقق جري...
# 32062    هجم دول جلز شاب دانيال ريدج شلس ربل عقد طول ام...
#                                ...
# 31014    امر سير يمس بطل فرد سيد بطل بلد بطل ربع تنس خس...
# 7392     جلس درة شرك دبي رطب سوق دبي الي انه تم حدد وعد...
# 1702     كتب ثقف علم جلس على لشء اسر سعة خمس نصف اليوم ...
# 8881     ربح شرك ارك خلل شهر تسع ولى عام الحالي نسب 7 2...
# 28572    برس دورتموند بين دفع مارسيل شميلتسر نضم قءم طو...
# Name: text, Length: 903, dtype: object

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train['text'])

label_encoder = LabelEncoder()

def techniques(data):

    data['text'] = tokenizer.texts_to_sequences(data['text'])
    data['text'] = pad_sequences(data['text'], maxlen=400, padding='post')

    data['label'] = label_encoder.fit_transform(data['label'])
    return data

train = techniques(train)
val = techniques(val)
test = techniques(test)

# %%
model = Sequential([
    Input(shape=(300,)),
    Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=128, input_length=300),

    Bidirectional(SimpleRNN(64, return_sequences=True)),


    Bidirectional(SimpleRNN(32)),


    Dense(64, activation='relu'),

    Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 300, 128)            │         582,016 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ (None, 300, 128)            │          24,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ (None, 64)                  │          10,304 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 621,249 (2.37 MB)
#  Trainable params: 621,249 (2.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Building the Classifier

# %% [markdown]
# In this step, you will design and build a NLP Classifier model to classify text data. Below is a breakdown of the key components you'll implement, but it's up to you to decide how to configure them based on your understanding and experimentation:
#
# 1. **Model Type**:
#    You will use a Sequential model, which allows you to stack layers in a linear sequence.
#
# 2. **Input Layer**:
#    Define the shape of the input data. Consider the dimensions of your padded sequences and set the input shape accordingly.
#
# 3. **Embedding Layer**:
#    The embedding layer will convert input tokens (integers) into dense vector representations. You will need to determine the size of the input dimension (based on your vocabulary) and the output dimension (embedding size).
#
# 4. **Bidirectional Simple RNN/LSTM Layers**:
#    You can add one or more recurrent layers. Consider using Bidirectional layers to capture contextual information from both directions (forward and backward). You can chose SimpleRNN/GRU/LSTM to perform this step.
#
# 5. **Dense Layers**:
#    Add one or more fully connected (Dense) layers to process the output from the RNN/GRU/LSTM layers.
#
# 6. **Output Layer**:
#    The output layer should match the type of classification task you're working on. Consider using appropriate activation function with appropriate number of units.
#
# 7. **Model Summary**:
#    After defining your model architecture, print a summary to review the number of layers, types of layers, and total parameters.
#
# 8. **Model Compilation**:
#    Finally, compile the model by selecting an optimizer, a loss function, and metrics.

# %%
history = model.fit(train['text'], train['label'], epochs=50, validation_data=(val['text'], val['label']),batch_size=32)
# Out:
# Epoch 1/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 47ms/step - accuracy: 0.3615 - loss: -0.0963 - val_accuracy: 0.4567 - val_loss: -6.1791
# Epoch 2/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.4106 - loss: -16.4437 - val_accuracy: 0.4808 - val_loss: -50.1073
# Epoch 3/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4190 - loss: -78.4409 - val_accuracy: 0.4615 - val_loss: -108.8754
# Epoch 4/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4083 - loss: -155.4154 - val_accuracy: 0.4615 - val_loss: -174.9519
# Epoch 5/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4005 - loss: -242.4365 - val_accuracy: 0.4615 - val_loss: -252.6715
# Epoch 6/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4159 - loss: -327.3984 - val_accuracy: 0.4712 - val_loss: -342.1692
# Epoch 7/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4380 - loss: -444.9995 - val_accuracy: 0.4712 - val_loss: -444.4811
# Epoch 8/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4231 - loss: -574.6701 - val_accuracy: 0.4712 - val_loss: -561.2521
# Epoch 9/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4221 - loss: -722.8372 - val_accuracy: 0.4712 - val_loss: -692.3815
# Epoch 10/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3979 - loss: -894.9905 - val_accuracy: 0.4712 - val_loss: -842.2274
# Epoch 11/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4129 - loss: -1060.2882 - val_accuracy: 0.4712 - val_loss: -1001.8536
# Epoch 12/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4270 - loss: -1188.5868 - val_accuracy: 0.4712 - val_loss: -1173.6495
# Epoch 13/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4339 - loss: -1436.0605 - val_accuracy: 0.4712 - val_loss: -1372.5610
# Epoch 14/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4176 - loss: -1735.3088 - val_accuracy: 0.4712 - val_loss: -1580.9985
# Epoch 15/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4145 - loss: -1955.5039 - val_accuracy: 0.4712 - val_loss: -1804.3906
# Epoch 16/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4158 - loss: -2192.1440 - val_accuracy: 0.4712 - val_loss: -2040.4427
# Epoch 17/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4352 - loss: -2323.9607 - val_accuracy: 0.4712 - val_loss: -2284.8989
# Epoch 18/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4555 - loss: -2643.6477 - val_accuracy: 0.4712 - val_loss: -2548.6892
# Epoch 19/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4200 - loss: -3151.4172 - val_accuracy: 0.4712 - val_loss: -2828.1987
# Epoch 20/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4424 - loss: -3385.0378 - val_accuracy: 0.4712 - val_loss: -3123.9949
# Epoch 21/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4221 - loss: -3835.3196 - val_accuracy: 0.4712 - val_loss: -3429.7217
# Epoch 22/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4037 - loss: -4295.1714 - val_accuracy: 0.4712 - val_loss: -3747.5537
# Epoch 23/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4390 - loss: -4372.3286 - val_accuracy: 0.4712 - val_loss: -4078.1890
# Epoch 24/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4531 - loss: -4787.1846 - val_accuracy: 0.4712 - val_loss: -4425.7808
# Epoch 25/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4189 - loss: -5393.2793 - val_accuracy: 0.4712 - val_loss: -4785.3760
# Epoch 26/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4496 - loss: -5707.6128 - val_accuracy: 0.4615 - val_loss: -5149.0459
# Epoch 27/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.4298 - loss: -6205.1309 - val_accuracy: 0.5000 - val_loss: -5527.8784
# Epoch 28/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4359 - loss: -6583.4946 - val_accuracy: 0.4712 - val_loss: -5832.3237
# Epoch 29/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4177 - loss: -7234.2388 - val_accuracy: 0.4712 - val_loss: -6228.8979
# Epoch 30/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4302 - loss: -7479.0908 - val_accuracy: 0.4615 - val_loss: -6649.3652
# Epoch 31/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.4446 - loss: -7633.4961 - val_accuracy: 0.4615 - val_loss: -7074.4932
# Epoch 32/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4223 - loss: -8536.2246 - val_accuracy: 0.4615 - val_loss: -7514.8281
# Epoch 33/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.4186 - loss: -9176.4492 - val_accuracy: 0.4615 - val_loss: -7963.2808
# Epoch 34/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4217 - loss: -9818.2549 - val_accuracy: 0.4712 - val_loss: -8254.5430
# Epoch 35/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4265 - loss: -9839.8271 - val_accuracy: 0.4712 - val_loss: -8649.6133
# Epoch 36/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4311 - loss: -10929.4463 - val_accuracy: 0.4712 - val_loss: -9127.6963
# Epoch 37/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4295 - loss: -11763.0029 - val_accuracy: 0.4712 - val_loss: -9603.8574
# Epoch 38/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4299 - loss: -11863.0312 - val_accuracy: 0.4712 - val_loss: -10088.6240
# Epoch 39/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3975 - loss: -13717.6143 - val_accuracy: 0.4712 - val_loss: -10610.7676
# Epoch 40/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4103 - loss: -13518.9121 - val_accuracy: 0.4712 - val_loss: -11111.1025
# Epoch 41/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4166 - loss: -14132.1191 - val_accuracy: 0.4712 - val_loss: -11639.8955
# Epoch 42/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4418 - loss: -14346.8311 - val_accuracy: 0.4712 - val_loss: -12185.3086
# Epoch 43/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4156 - loss: -15614.3066 - val_accuracy: 0.4712 - val_loss: -12733.6348
# Epoch 44/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4011 - loss: -16598.3164 - val_accuracy: 0.4712 - val_loss: -13284.2695
# Epoch 45/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4170 - loss: -16495.0391 - val_accuracy: 0.4712 - val_loss: -13847.4951
# Epoch 46/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.4347 - loss: -16634.2148 - val_accuracy: 0.4712 - val_loss: -14429.5557
# Epoch 47/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4082 - loss: -18401.7734 - val_accuracy: 0.4712 - val_loss: -15022.3232
# Epoch 48/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.4331 - loss: -18428.8750 - val_accuracy: 0.4712 - val_loss: -15622.1367
# Epoch 49/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4367 - loss: -18674.5215 - val_accuracy: 0.4712 - val_loss: -16227.6934
# Epoch 50/50
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4326 - loss: -19838.7910 - val_accuracy: 0.4712 - val_loss: -16863.5293

# %% [markdown]
# # Defining Batch Size, Creating Datasets, and Training the Model

# %% [markdown]
# In this step, you will define the batch size, create TensorFlow Datasets for both training and testing, and train the model. The key elements to consider are outlined below, and it is up to you to choose the specific configurations based on your preferences and experimentation:
#
# 1. **Batch Size**:
#    Select a batch size for training and testing. The batch size determines how many samples will be processed together in one forward and backward pass during training.
#
# 2. **Creating Datasets**:
#    Use TensorFlow’s `Dataset.from_tensor_slices()` to create datasets from the training and testing data.
#
# 3. **Batching the Datasets**:
#    Batch the datasets by grouping the data into batches of the specified size.
#
# 4. **Training the Model**:
#    Train the model by fitting it on the training dataset for a specified number of epochs. You will also need to provide the validation data to monitor the model’s performance on unseen data during training.
#
# 5. **Tracking Training History**:
#    During training, the model’s performance metrics (such as loss and accuracy) will be tracked over the epochs, and the results will be stored in the `history` object.

# %%
# solve it above

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# Once the model is trained, the next step is to evaluate its performance on the testing dataset.
#
# 1. **Evaluate the Model**:
#    You will use the `evaluate()` method to assess the model’s performance on the test dataset.
#
# 2. **Testing Dataset**:
#    Ensure that the testing dataset is properly prepared and batched, just like the training dataset.
#
# 4. **Loss Curve**:
#    A loss curve plots the loss values for both the training and validation datasets over the epochs.

# %%
print(model.evaluate(test['text'], test['label']))
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5019 - loss: -15224.9326
# [-15383.3251953125, 0.48322147130966187]

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %% [markdown]
# # Model Inference

# %% [markdown]
# In this step, you will use the trained model to make predictions on new, unseen data (inference). Here’s an outline of the key points:
#
# 1. **Create Test Sample**:
#    Create a string to test your modelm the goal here is to give the model Before making predictions, ensure that the new data is preprocessed in the same way as the training data. This includes tokenization, padding, and any other transformations you applied during the data preprocessing step. The data can be single text to see the result of the prediction.
#
# 2. **Model Prediction**:
#    Use the `predict()` method to feed new samples into the trained model and obtain predictions. The model will output probabilities or predicted class labels based on the type of classification task (binary or multi-class).
#
# 3. **Interpreting Predictions**:
#    The model will return probabilities for each class.

# %%
sample_txt = ["سوق التمور"]

sample_sequence = tokenizer.texts_to_sequences([clean_text(sample_txt[0])])

padded_sample_sequence = pad_sequences(sample_sequence, maxlen=300, padding='post')

predicted_label = model.predict(padded_sample_sequence)

print("pridected label:", label_encoder.inverse_transform([predicted_label.argmax()]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# pridected label: ['Culture']

# %% [markdown]
# # Notebook Question:
# - How did you handle text preprocessing? Why did you choose this approach?
#
# - Why did you choose this model design?
#
# - Why did you pick this number of layers or units for the model?
#
# - Why did you select these evaluation methods?
#
# - Does your model show signs of overfitting or underfitting? How do you know?
#
# - What changes could you make to improve the model and fix overfitting or underfitting?

# %% [markdown]
# Answer Here:

# %% [markdown]
# **Text Preprocessing**: Cleaned, tokenized, and padded the text to handle different input lengths. This standardizes the data for the model.
#
# **Model Design**: Choose LSTM to handle text sequences and capture patterns in the data.
#
# **Layers/Units**: The number of layers/units balances complexity and performance.
#
# **Evaluation Methods**: Used accuracy and loss curves to track performance and detect overfitting or underfitting.
#
# **Overfitting/Underfitting**: Overfitting is seen when validation loss increases while training loss drops. High losses suggest underfitting.
#
# **Improvements**: For overfitting, add dropout or regularization. For underfitting, increase model complexity or adjust hyperparameters.
